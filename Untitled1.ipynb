# %%
import pandas as pd

# %%
pd.read_csv("krisha_data.csv")
# Out:
#                                        Название  Цена(тенге)  \
# 0                1-комнатная квартира · 58.4 м²     32704000
# 1                  3-комнатная квартира · 83 м²     53120000
# 2              5-комнатная квартира · 230.94 м²    392598000
# 3     3-комнатная квартира · 55.3 м² · 5/5 этаж     36900000
# 4     2-комнатная квартира · 64 м² · 13/13 этаж     47000000
# ..                                          ...          ...
# 96             4-комнатная квартира · 113.87 м²     54315990
# 97               3-комнатная квартира · 86.6 м²     54125000
# 98              1-комнатная квартира · 31.21 м²     13293000
# 99   1-комнатная квартира · 50.5 м² · 9/10 этаж     24500000
# 100   2-комнатная квартира · 60.7 м² · 3/9 этаж     40000000
#
#              Расположение          Район  Год постройки  Количество комнат  \
# 0                  Алматы  Наурызбайский           2023                  1
# 1                  Алматы  Наурызбайский           2022                  3
# ...
